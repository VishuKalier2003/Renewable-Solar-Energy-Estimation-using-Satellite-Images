# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
resized = cv2.imread('solar_panel.png')
plt.imshow(resized)

# %%
canny_edge = cv2.Canny(resized, 30, 40)
plt.imshow(canny_edge)

# %%
sigma = 0.3
median = np.median(resized)

# %%
protopath = "D:/codes/Renewable-Solar-Energy-Estimation-using-Satellite-Images/models/edgeDetection/hed/deploy.prototxt"
modelpath = "D:/codes/Renewable-Solar-Energy-Estimation-using-Satellite-Images/models/edgeDetection/hed/hed_pretrained_bsds.caffemodel"
net = cv2.dnn.readNetFromCaffe(protopath, modelpath)

# %%
(H, W) = resized.shape[:2]

# %%
mean_pixel_values = np.average(resized, axis=(0, 1))
print(mean_pixel_values[0], mean_pixel_values[1], mean_pixel_values[2])
blob = cv2.dnn.blobFromImage(resized, scalefactor=2, size=(W, H), mean=(mean_pixel_values[0]+40, mean_pixel_values[1]+40, mean_pixel_values[2]+40), swapRB=True, crop=False)
# Out:
# 93.64873233795855 86.5348259070951 81.76278040703893

# %%
blob_for_plot = np.moveaxis(blob[0,:,:,:], 0, 2)
plt.imshow(blob_for_plot)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
